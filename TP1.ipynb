# %% [markdown]
# # TP1 : AMAL

# %% [markdown]
# ![image.png](attachment:58325e75-d55c-4018-8025-ace8dfd01cf0.png)

# %% [markdown]
# ![image.png](attachment:e6009f52-9245-41c4-a49e-0a346150b3a4.png)

# %% [markdown]
# Rappel : $u'(v(x)) = u'(v(x)) * v'(x)$

# %% [markdown]
# $ \frac{dL \circ h}{d\mathbf{x_i}}(x) = \frac{d}{d\mathbf{x_i}} L(h(\mathbf{x})) = \sum_{j}^{p}  \frac{dL(h(x))}{dh_j(x)} * \frac{dh_j(x)}{d\mathbf{x_i}} = \sum_{j}^{p} \frac{dL(h(x))}{dy_j} * \frac{dh_j(x)}{d\mathbf{x_i}} = \sum_{j}^{p} (\nabla L)_j * \frac{dh_j(x)}{d\mathbf{x_i}}$

# %% [markdown]
# ![image.png](attachment:3ebf3fba-18c0-45c2-ab87-2186a5de92de.png)

# %% [markdown]
# ![image.png](attachment:be15c8f3-3899-4aa7-ae7b-e98b29bbb971.png)

# %% [markdown]
# Comme $L$ est considérée comme une fonction générique pour simuler le chainage des dérivées, on considère $L(x) = x$, donc $L'(x) = 1$

# %% [markdown]
# $  \frac{d}{dy} L \circ mse(\hat{y},y) = \frac{d}{d mse(\hat{y},y) } L \circ mse(\hat{y},y) * \frac{d}{dy} mse(\hat{y},y) = 1 * \frac{d}{dy} ( \hat{y} - y )^2 = - 2 (\hat{y} - y) $

# %% [markdown]
# $  \frac{d}{d\hat{y}} L \circ mse(\hat{y},y) = \frac{d}{d mse(\hat{y},y) } L \circ mse(\hat{y},y) * \frac{d}{d\hat{y}} mse(\hat{y},y) = 1 * \frac{d}{d\hat{y}} ( \hat{y} - y )^2 = 2 (\hat{y} - y) $

# %% [markdown]
# $ \frac{d}{d \mathbf{x_j} } L \circ f(\mathbf{x},\mathbf{w},b) = \frac{d}{d f(\mathbf{x_j},\mathbf{w},b) } L \circ f(\mathbf{x},\mathbf{w},b) * \frac{d}{d \mathbf{x_j} } f(\mathbf{x_j},\mathbf{w},b) = 1 * \frac{d}{d \mathbf{x_j} } (\mathbf{x_j} * \mathbf{w_j} + b) = \mathbf{w_j}$

# %% [markdown]
# ![image.png](attachment:f486d8d3-5eda-4dbf-bf19-57f1cd3dc0b9.png)

# %% [markdown]
# ![image.png](attachment:3032950c-5a07-44dd-a9e2-2d01dd27d819.png)

# %% [markdown]
# $ \frac{d}{dY_{ij}} L \circ mse(\hat{Y},Y) = \frac{d}{d mse(\hat{Y_{ij}},Y_{ij})} L \circ mse(\hat{Y},Y) * \frac{d}{dY_{ij}} mse(\hat{Y_{ij}},Y_{ij}) = - \frac{2}{q} * (\hat{Y_{ij}} - Y_{ij})  $

# %% [markdown]
# $ \frac{d}{d\hat{Y_{ij}}} L \circ mse(\hat{Y},Y) = \frac{d}{d mse(\hat{Y_{ij}},Y_{ij})} L \circ mse(\hat{Y},Y) * \frac{d}{d\hat{Y_{ij}}} mse(\hat{Y_{ij}},Y_{ij}) = \frac{2}{q} * (\hat{Y_{ij}} - Y_{ij})  $

# %% [markdown]
# On considére dans la seconde partie $L(.) = mse(.,Y)$

# %% [markdown]
# $ \frac{d}{d \mathbf{X_{ij}} } mse(f(\mathbf{X},\mathbf{W},\mathbf{b}), Y) = \frac{d}{d f(\mathbf{X_{ij}},\mathbf{W},\mathbf{b}) } mse(f(\mathbf{X},\mathbf{W},\mathbf{b}), Y) * \frac{d}{d \mathbf{X_{ij}} } f(\mathbf{X_{ij}},\mathbf{W},\mathbf{b}) = \frac{d}{d \hat{Y_{i}} } mse(\hat{Y}, Y) * \frac{d}{d \mathbf{X_{ij}} } \sum_{k}^{p} X_{ij} * W_{jk} + b_{k} = \frac{2}{q} * \sum_{k}^{p} (\hat{Y_{ik}} - Y_{ik}) * \sum_{k}^{p}  * W_{jk}$

# %% [markdown]
# $ \frac{d}{d \mathbf{W_{ij}} } mse(f(\mathbf{X},\mathbf{W},\mathbf{b}), Y) = \frac{d}{d f(\mathbf{X},\mathbf{W_{ij}},\mathbf{b}) } mse(f(\mathbf{X},\mathbf{W},\mathbf{b}), Y) * \frac{d}{d \mathbf{W_{ij}} } f(\mathbf{X},\mathbf{W_{ij}},\mathbf{b}) = \frac{d}{d \hat{Y_{.j}} } mse(\hat{Y}, Y) * \frac{d}{d \mathbf{W_{ij}} } \sum_{k}^{p} X_{ki} * W_{ij} + b_{j}  = \frac{2}{q} * \sum_{k}^{p} (\hat{Y_{kj}} - Y_{kj}) * \sum_{k}^{p}  * X_{ki}$

# %% [markdown]
# $ \frac{d}{d \mathbf{b_{i}} } mse(f(\mathbf{X},\mathbf{W},\mathbf{b}), Y) = \frac{d}{d f(\mathbf{X},\mathbf{W},\mathbf{b_i}) } mse(f(\mathbf{X},\mathbf{W},\mathbf{b}), Y) * \frac{d}{d \mathbf{b_{i}} } f(\mathbf{X},\mathbf{W},\mathbf{b_i}) = \frac{d}{d  \hat{Y_{.i}} } mse(\hat{Y}, Y) * \frac{d}{d \mathbf{b_{i}} } \sum_{k}^{q} \sum_{z}^{n} X_{kz} * W_{zi} + b_{i} = \frac{2}{q} * \sum_{k}^{p} (\hat{Y_{ki}} - Y_{ki}) $

# %% [markdown]
# ![image.png](attachment:9f1f4cea-2cff-437b-9218-ab1045d518b5.png)

# %% [markdown]
# $ \frac{d}{dY} L \circ mse(\hat{Y},Y) = \frac{d}{d mse(\hat{Y},Y)} L \circ mse(\hat{Y},Y) * \frac{d}{dY} mse(\hat{Y},Y) = - \frac{2}{q} * (\hat{Y} - Y)$

# %% [markdown]
# $ \frac{d}{d \hat{Y}} L \circ mse(\hat{Y},Y) = \frac{d}{d mse(\hat{Y},Y)} L \circ mse(\hat{Y},Y) * \frac{d}{d\hat{Y}} mse(\hat{Y},Y) = \frac{2}{q} * (\hat{Y} - Y)$

# %% [markdown]
# $ \frac{d}{d \mathbf{X} } mse(f(\mathbf{X},\mathbf{W},\mathbf{b}), Y) = \frac{d}{d f(\mathbf{X},\mathbf{W},\mathbf{b}) } mse(f(\mathbf{X},\mathbf{W},\mathbf{b}), Y) * \frac{d}{d \mathbf{X} } f(\mathbf{X},\mathbf{W},\mathbf{b}) = \frac{d}{d \hat{Y} } mse(\hat{Y}, Y) * \frac{d}{d \mathbf{X} } <X , W> + b = \frac{2}{q} * (\hat{Y} - Y) . W^{T}$

# %% [markdown]
# $ \frac{d}{d \mathbf{W} } mse(f(\mathbf{X},\mathbf{W},\mathbf{b}), Y) = \frac{d}{d f(\mathbf{X},\mathbf{W},\mathbf{b}) } mse(f(\mathbf{X},\mathbf{W},\mathbf{b}), Y) * \frac{d}{d \mathbf{W} } f(\mathbf{X},\mathbf{W},\mathbf{b}) = \frac{d}{d \hat{Y} } mse(\hat{Y}, Y) * \frac{d}{d \mathbf{W} } <X , W> + b = X^{T}. \frac{2}{q} * (\hat{Y} - Y) $

# %% [markdown]
# $ \frac{d}{d \mathbf{b} } mse(f(\mathbf{X},\mathbf{W},\mathbf{b}), Y) = \frac{d}{d f(\mathbf{X},\mathbf{W},\mathbf{b}) } mse(f(\mathbf{X},\mathbf{W},\mathbf{b}), Y) * \frac{d}{d \mathbf{b} } f(\mathbf{X},\mathbf{W},\mathbf{b}) = \frac{d}{d \hat{Y} } mse(\hat{Y}, Y) * \frac{d}{d \mathbf{b} } <X , W> + b = \frac{2}{q} \sum_i^q (\hat{Y} - Y)_i $

# %% [markdown]
# # Code

# %%
# !python .\student_tp1_2021\student_tp1\src\tp1_descente.py # mettre le chemin du fichier tp1_descente.py
# Out:
# python: can't open file 'C:\Users\jerem\Desktop\Master ANDROIDE\M2\AMAL\AMAL\student_tp1_2021\student_tp1\src\tp1_descente.py': [Errno 2] No such file or directory

# %% [markdown]
# ![image.png](attachment:2ec58962-14dc-4dad-852d-813b1303a037.png)

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
from tqdm import tqdm
from torch.autograd import Function
from torch.autograd import gradcheck

# %%
l = [1,2,3,4,5]
print(l[:1] + l[1+1:])
# Out:
# [1, 3, 4, 5]

# %%
f = open(".\data\housing.data", "r")
index1 = 2
index2 = 5
list_index1 = list()
list_index2 = list()
for line in f:
    tab = line.split(" ")
    tab = [float(elmt.replace("\n","")) for elmt in tab if elmt != "" and elmt != " "]
    
    # list_index1.append( (tab[:index] + tab[index+1:]) )
    list_index1.append( tab[index1] )
    list_index2.append( tab[index2] )

# %%
class Context:
    """Un objet contexte très simplifié pour simuler PyTorch

    Un contexte différent doit être utilisé à chaque forward
    """
    def __init__(self):
        self._saved_tensors = ()
        
    def save_for_backward(self, *args):
        self._saved_tensors = args
    
    @property
    def saved_tensors(self):
        return self._saved_tensors


class MSE(Function):
    """Début d'implementation de la fonction MSE"""
    @staticmethod
    def forward(ctx, yhat, y):
        ## Garde les valeurs nécessaires pour le backwards
        ctx.save_for_backward(yhat, y)

        #  TODO:  Renvoyer la valeur de la fonction
        return torch.mean((yhat - y)**2,dim=0)

    @staticmethod
    def backward(ctx, grad_output):
        ## Calcul du gradient du module par rapport a chaque groupe d'entrées
        yhat, y = ctx.saved_tensors
        #  TODO:  Renvoyer par les deux dérivées partielles (par rapport à yhat et à y)
        return grad_output * 2 * (yhat - y) / yhat.shape[0] , grad_output * -2 * (yhat - y) / yhat.shape[0]
        
#  TODO:  Implémenter la fonction Linear(X, W, b)sur le même modèle que MSE

class Linear(Function) :

    @staticmethod
    def forward(ctx, X, W, B):
        ctx.save_for_backward(X, W, B)
        return X @ W + B

    @staticmethod
    def backward(ctx, grad_output):
        X, W, B = ctx.saved_tensors
        # Renvoit les derivees partielles par rapport a X , W , B
        return grad_output @ W.T, X.T @ grad_output, grad_output.T @ torch.ones(grad_output.shape[0]).double()

# %%
from torch.utils.tensorboard import SummaryWriter

x_array = np.asarray(list_index1, dtype=np.float32)
y_array = np.asarray(list_index2, dtype=np.float32)

# Les données supervisées
x = torch.as_tensor(x_array, dtype=torch.float64).unsqueeze(1)
y = torch.as_tensor(y_array, dtype=torch.float64).unsqueeze(1)

nb_data = x.shape[0]

print("shape x :",x.shape)
print("shape y :",y.shape)

# Les paramètres du modèle à optimiser
w = torch.randn(x.shape[1], 1, dtype=torch.float64)
b = torch.randn(1, dtype=torch.float64)

learning_rate = 0.0005
writer = SummaryWriter()
for n_iter in tqdm(range(1000)):
    ## TODO:  Calcul du forward (loss)
    ctx_lin = Context()
    yhat = Linear.forward(ctx_lin,x,w,b)
    
    ctx_mse = Context()
    loss = MSE.forward(ctx_mse,yhat,y)
    # `loss` doit correspondre au coût MSE calculé à cette itération
    # on peut visualiser avec
    # tensorboard --logdir runs/
    writer.add_scalar('Loss/train housing.data', loss.mean(), n_iter)
    
    ##  TODO:  Calcul du backward (grad_w, grad_b)
    
    yhat_back, _ = MSE.backward(ctx_mse,loss)
    _,grad_w,grad_b = Linear.backward(ctx_lin,yhat_back.double())
    ##  TODO:  Mise à jour des paramètres du modèle
    w -= learning_rate * grad_w / nb_data
    b -= learning_rate * grad_b / nb_data
# Out:
# shape x : torch.Size([506, 1])
# shape y : torch.Size([506, 1])
# 100%|████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 1439.09it/s]

# %% [markdown]
# ![image.png](attachment:9ec08f47-639f-4462-bca4-8a00507ff996.png)
