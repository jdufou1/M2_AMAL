# %% [markdown]
# # AMAL : TP3

# %%
from torch.utils.data import Dataset , DataLoader

# %%
class MonDataSet(Dataset) :
    
    def __init__(self) :
        pass
    
    def __getitem__(self,index) :
        """
        retourne couple exemple,label
        """
        return
    
    def __len__(self) :
        """
        renvoit la taille du jeu de données
        """
        return

# %%
dl = DataLoader(MonDataSet(), shuffle=True,batch_size=64)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4800/2971597277.py in <module>
# ----> 1 dl = DataLoader(MonDataSet(), shuffle=True,batch_size=64)
#
# ~/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __init__(self, dataset, batch_size, shuffle, sampler, batch_sampler, num_workers, collate_fn, pin_memory, drop_last, timeout, worker_init_fn, multiprocessing_context, generator, prefetch_factor, persistent_workers, pin_memory_device)
#     345             else:  # map-style
#     346                 if shuffle:
# --> 347                     sampler = RandomSampler(dataset, generator=generator)  # type: ignore[arg-type]
#     348                 else:
#     349                     sampler = SequentialSampler(dataset)  # type: ignore[arg-type]
#
# ...

# %% [markdown]
# ![image.png](attachment:a4aa2c8c-dda3-451a-9349-e91193c205ec.png)

# %%
from datamaestro import prepare_dataset

# %%
ds = prepare_dataset("com.lecun.mnist")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /tmp/ipykernel_4800/273128599.py in <module>
# ----> 1 ds = prepare_dataset("com.lecun.mnist")
#
# ~/.local/lib/python3.8/site-packages/datamaestro/context.py in prepare_dataset(dataset_id)
#     426     from .definitions import AbstractDataset
#     427
# --> 428     ds = AbstractDataset.find(dataset_id)
#     429     return ds.prepare(download=True)
#     430
#
# ~/.local/lib/python3.8/site-packages/datamaestro/definitions.py in find(name)
#     216             if dataset is not None:
#     217                 return dataset
# --> 218         raise Exception("Could not find the dataset %s" % (name))
#     219
#     220
#
# Exception: Could not find the dataset com.lecun.mnist
